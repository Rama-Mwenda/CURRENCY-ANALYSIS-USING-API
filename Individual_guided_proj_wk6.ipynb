# %% [markdown]
# ## *ANALYSING FOREX RATES WITH THE FRANKFURTER API* ##

# %% [markdown]
# ### Frankfurter is an open-source API for current and historical foreign exchange rates published by the European Central Bank.

# %%
#Import the relevant libraries
import pandas as pd
import requests
from pandas import json_normalize
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np


print('libraries loaded successdfy')
# Out:
# libraries loaded successdfy

# %%
#saving API link to url variable
URL = 'https://api.frankfurter.app/2013-01-01..2022-12-31'

# %%
#GET data
response = requests.get(URL)
#read the .json file response
data = response.json()
#convert it to a dataframe
df = pd.DataFrame(data)
df
# Out:
#             amount base  start_date    end_date  \
# 2012-12-31     1.0  EUR  2012-12-31  2022-12-26
# 2013-01-07     1.0  EUR  2012-12-31  2022-12-26
# 2013-01-14     1.0  EUR  2012-12-31  2022-12-26
# 2013-01-21     1.0  EUR  2012-12-31  2022-12-26
# 2013-01-28     1.0  EUR  2012-12-31  2022-12-26
# ...            ...  ...         ...         ...
# 2022-11-28     1.0  EUR  2012-12-31  2022-12-26
# 2022-12-05     1.0  EUR  2012-12-31  2022-12-26
# 2022-12-12     1.0  EUR  2012-12-31  2022-12-26
# 2022-12-19     1.0  EUR  2012-12-31  2022-12-26
# 2022-12-26     1.0  EUR  2012-12-31  2022-12-26
#
#                                                         rates
# 2012-12-31  {'AUD': 1.2534, 'BGN': 1.9558, 'BRL': 2.6831, ...
# 2013-01-07  {'AUD': 1.2454, 'BGN': 1.9558, 'BRL': 2.6658, ...
# 2013-01-14  {'AUD': 1.2649, 'BGN': 1.9558, 'BRL': 2.7182, ...
# 2013-01-21  {'AUD': 1.2713, 'BGN': 1.9558, 'BRL': 2.7238, ...
# 2013-01-28  {'AUD': 1.2985, 'BGN': 1.9558, 'BRL': 2.7009, ...
# ...                                                       ...
# 2022-11-28  {'AUD': 1.5461, 'BGN': 1.9558, 'BRL': 5.5142, ...
# 2022-12-05  {'AUD': 1.5608, 'BGN': 1.9558, 'BRL': 5.5193, ...
# 2022-12-12  {'AUD': 1.565, 'BGN': 1.9558, 'BRL': 5.6133, '...
# 2022-12-19  {'AUD': 1.5857, 'BGN': 1.9558, 'BRL': 5.5539, ...
# 2022-12-26  {'AUD': 1.5746, 'BGN': 1.9558, 'BRL': 5.597, '...
#
# [522 rows x 5 columns]

# %%
#normalize rates column using json_normalize
df_rates = json_normalize(df['rates'])
df_rates
# Out:
#         AUD     BGN     BRL     CAD      CHF     CNY     CZK     DKK      GBP  \
# 0    1.2534  1.9558  2.6831  1.2960  1.20910  8.1813  25.278  7.4597  0.81235
# 1    1.2454  1.9558  2.6658  1.2930  1.21060  8.1627  25.579  7.4605  0.81633
# 2    1.2649  1.9558  2.7182  1.3157  1.23720  8.2884  25.597  7.4626  0.83257
# 3    1.2713  1.9558  2.7238  1.3324  1.24100  8.3096  25.608  7.4629  0.84293
# 4    1.2985  1.9558  2.7009  1.3572  1.23950  8.4169  25.652  7.4605  0.85702
# ..      ...     ...     ...     ...      ...     ...     ...     ...      ...
# 517  1.5461  1.9558  5.5142  1.4061  0.98580  7.4198  24.352  7.4369  0.86176
# 518  1.5608  1.9558  5.5193  1.4320  0.98806  7.3468  24.321  7.4378  0.86174
# 519  1.5650  1.9558  5.6133  1.4432  0.98660  7.3872  24.280  7.4386  0.86261
# 520  1.5857  1.9558  5.5539  1.4463  0.98586  7.4089  24.219  7.4376  0.87714
# 521  1.5746  1.9558  5.5970  1.4415  0.98588  7.3988  24.205  7.4365  0.88408
#
#          HKD  ...     PLN     RON     RUB      SEK     SGD     THB      TRY  \
# 0    10.1738  ...  4.0925  4.4281  39.796   8.5471  1.6072  39.909   2.3412
# 1    10.1650  ...  4.1083  4.3994  39.793   8.5756  1.6094  39.818   2.3299
# 2    10.3323  ...  4.1274  4.3564  40.374   8.6386  1.6330  39.884   2.3541
# 3    10.3566  ...  4.1750  4.3650  40.287   8.6904  1.6409  39.804   2.3626
# 4    10.4907  ...  4.1961  4.3848  40.662   8.6231  1.6743  40.348   2.3862
# ..       ...  ...     ...     ...     ...      ...     ...     ...      ...
# 517   8.1419  ...  4.6828  4.9257     NaN  10.9066  1.4243  36.744  19.4506
# 518   8.2021  ...  4.6930  4.9176     NaN  10.9052  1.4267  36.736  19.6516
# 519   8.2414  ...  4.6897  4.9259     NaN  10.9162  1.4348  36.906  19.7648
# 520   8.2716  ...  4.6628  4.9044     NaN  11.0569  1.4357  36.875  19.8189
# 521   8.2990  ...  4.6838  4.9430     NaN  11.1280  1.4321  36.860  19.9233
#
#         USD      ZAR     ISK
# 0    1.3125  11.2497     NaN
# 1    1.3114  11.3051     NaN
# 2    1.3327  11.7232     NaN
# 3    1.3358  11.9565     NaN
# 4    1.3522  12.1687     NaN
# ..      ...      ...     ...
# 517  1.0439  17.9863  147.66
# 518  1.0542  18.1608  149.10
# 519  1.0599  18.4884  150.74
# 520  1.0618  18.2826  152.22
# 521  1.0645  18.2256  152.05
#
# [522 rows x 34 columns]

# %%
# reset the index for the df_rates
df = df.reset_index()
#drop rates
df = df.drop('rates', axis = 1)
#df dataframe
df = pd.concat([df, df_rates], axis = 1)

df
# Out:
#           index  amount base  start_date    end_date     AUD     BGN     BRL  \
# 0    2012-12-31     1.0  EUR  2012-12-31  2022-12-26  1.2534  1.9558  2.6831
# 1    2013-01-07     1.0  EUR  2012-12-31  2022-12-26  1.2454  1.9558  2.6658
# 2    2013-01-14     1.0  EUR  2012-12-31  2022-12-26  1.2649  1.9558  2.7182
# 3    2013-01-21     1.0  EUR  2012-12-31  2022-12-26  1.2713  1.9558  2.7238
# 4    2013-01-28     1.0  EUR  2012-12-31  2022-12-26  1.2985  1.9558  2.7009
# ..          ...     ...  ...         ...         ...     ...     ...     ...
# 517  2022-11-28     1.0  EUR  2012-12-31  2022-12-26  1.5461  1.9558  5.5142
# 518  2022-12-05     1.0  EUR  2012-12-31  2022-12-26  1.5608  1.9558  5.5193
# 519  2022-12-12     1.0  EUR  2012-12-31  2022-12-26  1.5650  1.9558  5.6133
# 520  2022-12-19     1.0  EUR  2012-12-31  2022-12-26  1.5857  1.9558  5.5539
# 521  2022-12-26     1.0  EUR  2012-12-31  2022-12-26  1.5746  1.9558  5.5970
#
#         CAD      CHF  ...     PLN     RON     RUB      SEK     SGD     THB  \
# 0    1.2960  1.20910  ...  4.0925  4.4281  39.796   8.5471  1.6072  39.909
# 1    1.2930  1.21060  ...  4.1083  4.3994  39.793   8.5756  1.6094  39.818
# 2    1.3157  1.23720  ...  4.1274  4.3564  40.374   8.6386  1.6330  39.884
# 3    1.3324  1.24100  ...  4.1750  4.3650  40.287   8.6904  1.6409  39.804
# 4    1.3572  1.23950  ...  4.1961  4.3848  40.662   8.6231  1.6743  40.348
# ..      ...      ...  ...     ...     ...     ...      ...     ...     ...
# 517  1.4061  0.98580  ...  4.6828  4.9257     NaN  10.9066  1.4243  36.744
# 518  1.4320  0.98806  ...  4.6930  4.9176     NaN  10.9052  1.4267  36.736
# 519  1.4432  0.98660  ...  4.6897  4.9259     NaN  10.9162  1.4348  36.906
# 520  1.4463  0.98586  ...  4.6628  4.9044     NaN  11.0569  1.4357  36.875
# 521  1.4415  0.98588  ...  4.6838  4.9430     NaN  11.1280  1.4321  36.860
#
#          TRY     USD      ZAR     ISK
# 0     2.3412  1.3125  11.2497     NaN
# 1     2.3299  1.3114  11.3051     NaN
# 2     2.3541  1.3327  11.7232     NaN
# 3     2.3626  1.3358  11.9565     NaN
# 4     2.3862  1.3522  12.1687     NaN
# ..       ...     ...      ...     ...
# 517  19.4506  1.0439  17.9863  147.66
# 518  19.6516  1.0542  18.1608  149.10
# 519  19.7648  1.0599  18.4884  150.74
# 520  19.8189  1.0618  18.2826  152.22
# 521  19.9233  1.0645  18.2256  152.05
#
# [522 rows x 39 columns]

# %%
#converting columns to datetime
df['index'] = pd.to_datetime(df['index'])
df['start_date'] = pd.to_datetime(df['start_date'])
df['end_date'] = pd.to_datetime(df['end_date'])

#confirming the datatypes 
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 522 entries, 0 to 521
# Data columns (total 39 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   index       522 non-null    datetime64[ns]
#  1   amount      522 non-null    float64
#  2   base        522 non-null    object
#  3   start_date  522 non-null    datetime64[ns]
#  4   end_date    522 non-null    datetime64[ns]
#  5   AUD         522 non-null    float64
#  6   BGN         522 non-null    float64
#  7   BRL         522 non-null    float64
#  8   CAD         522 non-null    float64
#  9   CHF         522 non-null    float64
#  10  CNY         522 non-null    float64
#  11  CZK         522 non-null    float64
#  12  DKK         522 non-null    float64
#  13  GBP         522 non-null    float64
#  14  HKD         522 non-null    float64
#  15  HRK         522 non-null    float64
#  16  HUF         522 non-null    float64
#  17  IDR         522 non-null    int64
#  18  ILS         522 non-null    float64
#  19  INR         522 non-null    float64
#  20  JPY         522 non-null    float64
#  21  KRW         522 non-null    float64
#  22  LTL         105 non-null    float64
#  23  LVL         53 non-null     float64
#  24  MXN         522 non-null    float64
#  25  MYR         522 non-null    float64
#  26  NOK         522 non-null    float64
#  27  NZD         522 non-null    float64
#  28  PHP         522 non-null    float64
#  29  PLN         522 non-null    float64
#  30  RON         522 non-null    float64
#  31  RUB         479 non-null    float64
#  32  SEK         522 non-null    float64
#  33  SGD         522 non-null    float64
#  34  THB         522 non-null    float64
#  35  TRY         522 non-null    float64
#  36  USD         522 non-null    float64
#  37  ZAR         522 non-null    float64
#  38  ISK         257 non-null    float64
# dtypes: datetime64[ns](3), float64(34), int64(1), object(1)
# memory usage: 159.2+ KB

# %% [markdown]
# **The dataset has 38 columns and 522 entries.**
# **There are 4 different datatypes in the dataset, the float and int carry the currency prices and the object is the name of the base currency, while datetime carries the dates**

# %%
# Summary Stats for exchange rates
summary = df_rates.describe().reset_index().T
summary.head()
# Out:
#            0         1         2       3         4        5         6       7
# index  count      mean       std     min       25%      50%       75%     max
# AUD    522.0  1.522468   0.09275   1.229  1.461625  1.53175    1.5909  1.8383
# BGN    522.0    1.9558       0.0  1.9558    1.9558   1.9558    1.9558  1.9558
# BRL    522.0  4.357603  1.170568  2.5497  3.379425  4.21545  5.220625   6.801
# CAD    522.0  1.458161  0.067073   1.293   1.41605   1.4657  1.508625  1.5971

# %% [markdown]
# **QUESTION ONE: HOW HAS THE EXCHANGE RATE OF THE EURO AGAINST THE $ DOLLAR CHANGED OVER TIME**

# %%
#define the plot size
plt.figure(figsize = (15, 5))
#make the lineplot
sns.lineplot(x='index', y='USD', data=df,)
#remove the borders
sns.despine(bottom = False, left = False)
#define the max and min points in the trend
max_point = df.loc[df['USD'].idxmax()]
min_point = df.loc[df['USD'].idxmin()]
# Annotate max point
plt.annotate(f'Max: {max_point["USD"]:.2f}', 
             xy=(max_point['index'], max_point['USD']),
             xytext=(-40, 10),
             textcoords='offset points',
             arrowprops=dict(arrowstyle="->", lw=1))
# Annotate min point
plt.annotate(f'Min: {min_point["USD"]:.2f}', 
             xy=(min_point['index'], min_point['USD']),
             xytext=(20, 20),
             textcoords='offset points',
             arrowprops=dict(arrowstyle="->", lw=1))
#add chart title
plt.title(f'EUR-USD EXCHANGE TREND OVER TIME\n 2013 - 2023')
#show the plot
plt.show()

# %% [markdown]
# The trend of the euro against the dollar chart shows that USD has been steadliy gaining on EUR over the period of 10 years.
#
# The lowest point was 1.39 USD per EUR and the highest point was 0.97 USD per EUR

# %% [markdown]
# **QUESTION TWO: WHAT IS THE DISTRIBUTION OF EXCHANGE RATES FOR THE CHINESES YUAN AGAINST THE EURO**

# %%
#select the CNY column
eur_cny = df['CNY']
# define the plot size
plt.figure(figsize = (14, 6))
#plot the histogram
sns.histplot(data = eur_cny, bins=20, kde=True, color='Blue')
# remove the unwanted borders
sns.despine(left = False, bottom = False)
# Adding labels and title
plt.xlabel('EUR-CNY')
plt.ylabel('Frequency of Distribution')
plt.title(f'EUR - CNY DISTRIBUTION\n 2013 - 2023')
#show the plot
plt.show()

# %% [markdown]
# **QUESTION THREE: BETWEEN THE GREAT BRITISH POUND AND THE JAPANESE YEN DETERMINE WHICH COUNTRY'S CURRENCY IS MORE VOLATILE**

# %% [markdown]
# *To calculate currency volatility, you need to:*
#  - Choose a time period and record the highest and lowest exchange rates for the currency pair you are interested in.
#  - Calculate the difference between the highest and lowest exchange rates for each day or interval within the time period.
#  - Add all of the differences together and divide this number by the total number of differences you recorded. This will give you the average difference or the mean deviation.
#  - Divide the standard deviation by the average difference and multiply the result by 100. This will give you the volatility rating as a percentage. The higher the percentage, the more volatile the currency pair is.

# %%
#the highest and lowest exchange rates for gbp and yen
gbp_high = df['GBP'].max()
gbp_low = df['GBP'].min()
jpy_high = df['JPY'].max()
jpy_low = df['JPY'].min()

# %%
#difference between highest and lowest for each day gbp
daily_high_gbp = gbp_high - df['GBP']
daily_low_gbp = df['GBP'] - gbp_low
#sum of all daily differences
diff_gbp = daily_high_gbp.sum() + daily_low_gbp.sum()

# %%
#difference between highest and lowest for each day jpy
daily_high_jpy = jpy_high - df['JPY']
daily_low_jpy = df['JPY'] - jpy_low
#sum of all daily differences
diff_jpy = daily_high_jpy.sum() + daily_low_jpy.sum()

# %%
#add all the differences and divide by the count for the mean deviation
gbp_mean_dev = diff_gbp / df['GBP'].count()
jpy_mean_dev = diff_jpy / df['JPY'].count()

# %%
#converting to percentage
gbp_vol = (df['GBP'].std() / gbp_mean_dev)*100
jpy_vol = (df['JPY'].std() / jpy_mean_dev)*100

# %%
#saving volatilities to a dictionary
vol_comp = {'GBP':gbp_vol, 'JPY':jpy_vol}
plot = pd.DataFrame(vol_comp.items())
plot
# Out:
#      0          1
# 0  GBP  23.298159
# 1  JPY  21.776633

# %%
# Create an array with the colors to use
colors = ["#492E87", "#37B5B6"]
#plotting the volatility
ax = sns.barplot(x=0, y =1, data = plot, hue = 0, palette = colors)
# Add data labels to the bars 
for c in ax.containers:     
    ax.bar_label(c,) 
#add title
plt.xlabel("CURRENCY")
plt.ylabel("% VOLATILITY")
plt.title(f"PERCENTAGE VOLATILITY OF GBP AND JPY AGAINST THE EUR\n 2013 - 2023")
plt.show()

# %% [markdown]
# The chart shows that GBP has higher volatility than JPY by approximately 2.6 percentage points.

# %% [markdown]
# **QUESTION FOUR: IS THERE A CORRELATION BETWEEN THE EXCHANGE RATES OF THE CANADIAN DOLLAR AND THE AMERICAN DOLLAR**

# %%
#plotting the correlation using regplot
plt.figure(figsize = (15, 5))
sns.regplot(data=df, x='CAD', y='USD')
plt.title(f'CORRELATION GRAPH FOR USD AND CAD\n2013 - 2023')
plt.xlabel('CAD')
plt.ylabel('USD')
plt.show()

# %% [markdown]
# The regplot shows there is some linear correlation between the USD and CAD currencies but it is not very strong
